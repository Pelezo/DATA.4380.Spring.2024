# %%
import os
import numpy as np
import keras
from keras import layers
from tensorflow import data as tf_data
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# Out:
# 2024-08-03 21:13:49.220507: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/catarinavuzi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# #### **Crack Detection: Image Classification | Kaggle**
#
# - This notebook contains the loaded data.This is a computer vision project, so I am working with images.
#
# - For the project, I will be working with only 100 images for each category(cracked/uncracked)
#
# - In this notebook I created a new folder called cracked_uncracked_images that will contain 2 folders for each category.
#
# - The 100 images were manually copied and pasted to each folder.
#
# - For the data preprocessing the unecessary images should be removed. For this case there weren't any because 0 images were deleted.
#
# - The data was splited into training and validation sets and applied the data augmentation.

# %%
# !pwd
# Out:
# /Users/catarinavuzi

# %%
# !mkdir cracked_uncracked_images

# %%
# !ls
# Out:
# Applications
# Data_4380
# Data_loader.ipynb
# Datasets
# Desktop
# Documents
# Downloads
# End_to_End_dataProject.ipynb
# HiggsBosonCompetition_AMSMetric_rev1.py
# Library
# Movies
# Music
# My_projects
# Pictures
# Public
# ReadMe.txt
# Untitled1.ipynb
# a-10.txt
# a-11.txt
# a-12.txt
# a-13.txt
# computer_vision_project.ipynb
# crack-identification-ce784a-2020-iitk.zip
# cracked
# cracked_uncracked_images
# df_orders.db
# first_db.sqlite
# hello-dockeer
# hello-docker
# iCloud Drive (Archive)
# input_data
# jo_wilder
# jo_wilder_310
# kagglecrack-identification-ce784a-2020-iitk.zip
# mushrooms.csv
# my_pi.py
# orders.csv
# orders.csv.zip
# sample-2submission.csv
# sample-submission.csv
# sample.json
# sample_submission.csv
# sample_submission.csv.zip
# test.csv
# test.csv.zip
# test.zip
# test_Hor.csv
# test_St.csv
# test_cir.csv
# test_data.csv
# test_folder
# test_m.csv
# test_p.csv
# test_soft.csv
# test_ver2.csv.zip
# train.csv
# train.csv.zip
# train_Hor.csv
# train_St.csv
# ...

# %%
cd cracked_uncracked_images
# Out:
# [Errno 2] No such file or directory: 'cracked_uncracked_images'
# /Users/catarinavuzi/Downloads/cracked_uncracked_images
# /Library/Python/3.9/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
# !mkdir cracked

# %%
# !mkdir uncracked

# %%
# !ls
# Out:
# cracked   uncracked

# %%
cd cracked
# Out:
# /Users/catarinavuzi/cracked_uncracked_images/cracked

# %%
pwd
# Out:
# '/Users/catarinavuzi/cracked_uncracked_images/cracked'

# %%
# !ls
# Out:
# 101.jpg 123.jpg 146.jpg 159.jpg 170.jpg 189.jpg 21.jpg  41.jpg  6.jpg   8.jpg
# 102.jpg 13.jpg  148.jpg 16.jpg  172.jpg 19.jpg  28.jpg  45.jpg  61.jpg  82.jpg
# 103.jpg 130.jpg 149.jpg 161.jpg 173.jpg 191.jpg 29.jpg  46.jpg  62.jpg  83.jpg
.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# Applications
# Data_4380
# Data_loader.ipynb
# Datasets
# Desktop
# Documents
# Downloads
# End_to_End_dataProject.ipynb
# HiggsBosonCompetition_AMSMetric_rev1.py
# Library
# Movies
# Music
# My_projects
# Pictures
# Public
# ReadMe.txt
# Untitled1.ipynb
# a-10.txt
# a-11.txt
# a-12.txt
# a-13.txt
# computer_vision_project.ipynb
# crack-identification-ce784a-2020-iitk.zip
# cracked
# df_orders.db
# first_db.sqlite
# hello-dockeer
# hello-docker
# iCloud Drive (Archive)
# input_data
# jo_wilder
# jo_wilder_310
# kagglecrack-identification-ce784a-2020-iitk.zip
# mushrooms.csv
# my_pi.py
# orders.csv
# orders.csv.zip
# sample-2submission.csv
# sample-submission.csv
# sample.json
# sample_submission.csv
# sample_submission.csv.zip
# test.csv
# test.csv.zip
# test.zip
# test_Hor.csv
# test_St.csv
# test_cir.csv
# test_data.csv
# test_folder
# test_m.csv
# test_p.csv
# test_soft.csv
# test_ver2.csv.zip
# train.csv
# train.csv.zip
# train_Hor.csv
# train_St.csv
# train_cir.csv
# ...

# %%
cd Downloads
# Out:
# /Users/catarinavuzi/Downloads

# %%
pwd
# Out:
# '/Users/catarinavuzi/Downloads'

# %%
# !ls
# Out:
# cracked   uncracked

# %%
#num_skipped = 0
#for folder_name in ("cracked", "uncracked"):
#  max_images = 100
#  folder_path = os.path.join("/Users/catarinavuzi/Downloads/cracked_uncracked_images", folder_name)
#  for image_i,fname in enumerate(os.listdir(folder_path)):
#    fpath = os.path.join(folder_path, fname)
#    try:
#      fobj = open(fpath, "rb")
#      is_jfif = b"JFIF" in fobj.peek(10)
#    finally:
#     fobj.close()

#    if image_i > max_images or not is_jfif:
#      num_skipped += 1
#      # Delete corrupted image
#      os.remove(fpath)

#print(f"Deleted {num_skipped} images.")
# Out:
# Deleted 0 images.

# %%
#image_size = (180, 180)
image_size = (224, 224)

batch_size = 10

train_ds, val_ds = keras.utils.image_dataset_from_directory(
    "/Users/catarinavuzi/Downloads/cracked_uncracked_images",
    validation_split=0.2,
    subset="both",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 200 files belonging to 2 classes.
# Using 160 files for training.
# Using 40 files for validation.

# %%
##Taking a look to the images
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# 2024-08-03 21:14:57.817884: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
]


def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
# Out:
# 2024-08-03 21:15:08.570347: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Apply `data_augmentation` to the training images.
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf_data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf_data.AUTOTUNE)
val_ds = val_ds.prefetch(tf_data.AUTOTUNE)
